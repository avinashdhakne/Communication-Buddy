# %%
import cv2
import numpy as np
from keras.models import load_model
from keras.preprocessing import image
import tensorflow as tf
import matplotlib.pyplot as plt
# import required libraries
import sounddevice as sd
from scipy.io.wavfile import write
import wavio as wv
import os 
import shutil
import librosa

# %%
model = tf.keras.models.load_model('model4.h5')
speech_model = tf.keras.models.load_model("speech_model.h5")

# %%
final_results={1:'mask',0:'without mask'}
GR_dict={1:(0,255,0),0:(0,0,255)}

# %%
dict = {0:'Fear',1:'Happiness',2:'Sadness',3:'Neutral'}
dict1 = {0:'happy',1:'Happiness',2:'Neutral',3:'Sadness'}
# a=model.predict(X_test[i].reshape(1,48,48,1))
# print("Predicted:",dict[np.argmax(a)]," Actual:",dict[np.argmax(y_test[i])])

# %%
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
def extract_mfcc(filename):
    y, sr = librosa.load(filename, duration=3, offset=0.5)
    mfcc = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T, axis=0)
    return mfcc

# %%
cap = cv2.VideoCapture(0)

while True:
    try:
        shutil.rmtree('songs')
    except:
        print("unable to delete previous audio data or no song folder is present")
        
    count = 0
    ret, img = cap.read()
    print(ret)
#     gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(img,1.05,5)
    
    for x,y,w,h in faces:
        
        face_img = img[y:y+h,x:x+w ]
#         resized = np.array(face_img,target_size=(128,128))
        resized = cv2.resize(face_img,(48,48))
        resized = np.array(tf.image.rgb_to_grayscale(resized,name = None)/255)
        reshaped=resized.reshape(1, 48, 48, 1)
        result = model.predict(reshaped)
        a = dict[np.argmax(result)]
        print(result)
        # a=model.predict(X_test[i].reshape(1,48,48,1))
        # print("Predicted:",dict[np.argmax(a)]," Actual:",dict[np.argmax(y_test[i])])
        
#         label = np.argmax(result,axis=1)[0]
        
        cv2.rectangle(img,(x,y),(x+w,y+h),GR_dict[1],2)
        cv2.rectangle(img,(x,y-40),(x+w,y),GR_dict[1],-1)
        cv2.putText(img, a, (x, y-10),cv2.FONT_HERSHEY_SIMPLEX,0.8,(255,255,255),2)
        
        # Sampling frequency
        freq = 44100

        # Recording duration
        duration = 1

        # Start recorder with the given values 
        # of duration and sample frequency
        recording = sd.rec(int(duration * freq), 
                           samplerate=freq, channels=1)

        # Record audio for the given number of seconds
        sd.wait()

        # This will convert the NumPy array to an audio
        # file with the given sampling frequency
        # write("recording0.wav", freq, recording)
            
        try:
            os.mkdir("songs")
        except:
            print("directry is already present")

        # Convert the NumPy array to audio file
        filename = "songs/recording"+str(count)+".wav"
        wv.write(filename, recording, freq, sampwidth=2)
        
        feature = extract_mfcc(filename)
        
        feature = np.array([feature])
        feature = feature.reshape(1, 40, 1)
        
        audio_result = speech_model.predict(feature)
        audio_result = np.argmax(audio_result)
        audio_result = dict1[audio_result]
        print(audio_result)
        
        count += 1
        
        cv2.putText(img, audio_result, (50,50),cv2.FONT_HERSHEY_SIMPLEX,0.8,(0,0,0))
            
    cv2.imshow('LIVE', img)
    key = cv2.waitKey(1)
    
    if key == 27: 
        break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# True
# [[0.00274134 0.88296807 0.04049175 0.07379895]]
# happy
# True
# [[0.01379409 0.7265489  0.1895593  0.0700977 ]]
# happy
# True
# [[0.02425578 0.37453735 0.24747835 0.35372856]]
# happy
# True
# [[0.01704395 0.07727098 0.11791659 0.7877685 ]]
# happy
# True
# [[0.01984727 0.01877535 0.11563686 0.84574056]]
# happy
# True
# [[0.0167596  0.05500131 0.14359286 0.7846462 ]]
# happy
# True
# [[0.44122946 0.01772739 0.44116154 0.09988157]]
# happy
# [[0.19977869 0.12807931 0.6046772  0.06746472]]
# directry is already present
# happy
# True
# [[0.0383913  0.18111685 0.25097    0.5295219 ]]
# happy
# True
# [[0.48788905 0.01318327 0.394042   0.10488568]]
# happy
# [[0.05001317 0.16743493 0.67315626 0.10939571]]
# directry is already present
# happy
# True
# [[0.00358072 0.50378776 0.11475446 0.37787712]]
# happy
# True
# [[0.5154051  0.00112256 0.39671403 0.08675834]]
# happy
# [[0.14299358 0.28676215 0.4922078  0.07803644]]
# directry is already present
# happy
# True
# [[0.40344593 0.00160718 0.42292047 0.17202637]]
# happy
# [[0.03818451 0.01399413 0.30408877 0.6437326 ]]
# directry is already present
# happy
# True
# [[0.01533105 0.16269007 0.09668683 0.725292  ]]
# happy
# True
# [[0.01032792 0.30721003 0.23892485 0.44353718]]
# happy
# True
# [[0.00933603 0.45221207 0.09914564 0.4393063 ]]
# happy
# True
# [[0.47032192 0.00185684 0.4221183  0.10570296]]
# Sadness
# [[0.01338301 0.22220643 0.4074149  0.35699564]]
# directry is already present
# happy
# True
# [[0.04594517 0.01006369 0.16879721 0.775194  ]]
# happy
# True
# [[0.03277074 0.01014195 0.08475775 0.87232965]]
# happy
# True
# [[0.08985193 0.36548933 0.52899    0.01566876]]
# happy
# [[0.08201557 0.02687498 0.32004604 0.57106346]]
# directry is already present
# Sadness
# True
# [[0.01420111 0.2833242  0.13179527 0.57067937]]
# Sadness
# True
# [[0.00672724 0.01169364 0.0265308  0.9550484 ]]
# Sadness
# True
# [[0.040431   0.00398847 0.09297977 0.8626008 ]]
# Sadness
# True
# [[0.0081332  0.13620453 0.02089234 0.8347699 ]]
# happy
# True
# [[0.1749533  0.02940189 0.11871367 0.6769311 ]]
# Sadness
# True
# [[9.0608286e-04 1.7168650e-02 5.9108087e-03 9.7601444e-01]]
# happy
# True
# [[0.0162949  0.17811927 0.05654073 0.74904513]]
# Happiness
# True
# [[0.02379499 0.00194263 0.12839857 0.8458637 ]]
# Sadness
# True
# [[2.2821496e-03 7.1280729e-04 7.7309334e-03 9.8927408e-01]]
# Happiness
# True
# [[0.00130648 0.00142194 0.00522006 0.9920515 ]]
# Sadness
# True
# [[0.01964456 0.00130525 0.05158772 0.9274624 ]]
# Sadness
# True
# [[0.01139497 0.00857974 0.06461024 0.9154151 ]]
# Happiness
# True
# [[0.00249922 0.00429538 0.04032687 0.95287853]]
# Sadness
# True
# [[1.6689997e-02 9.2891301e-04 2.0888250e-02 9.6149290e-01]]
# happy
# True
# [[0.00359906 0.00144976 0.02307422 0.97187704]]
# happy
# True
# [[0.00221129 0.8592621  0.01158087 0.12694575]]
# Happiness
# True
# [[0.08562369 0.00196057 0.6740203  0.23839542]]
# happy
# True
# [[0.00325906 0.05734423 0.02357349 0.9158233 ]]
# Happiness
# True
# [[4.4539780e-04 7.7842391e-01 2.1724259e-03 2.1895830e-01]]
# Happiness
# True
# [[0.00248233 0.01030415 0.01446149 0.9727519 ]]
# Sadness
# True
# [[0.04588807 0.06711455 0.15593942 0.7310579 ]]
# Sadness
# True
# [[0.00083801 0.5934126  0.00827727 0.39747208]]
# Sadness
# True
# [[0.00522752 0.00484861 0.06145016 0.9284738 ]]
# happy
# True
# [[0.00425661 0.03255085 0.02583821 0.9373543 ]]
# Happiness
# True
# [[0.0018092  0.00568699 0.00815601 0.9843478 ]]
# happy
# True
# [[0.07602966 0.09457182 0.46942216 0.35997623]]
# Happiness
# True
# [[0.00439997 0.1271905  0.02127069 0.8471389 ]]
# Sadness
# True
# [[8.1698917e-02 4.3271389e-04 2.0220892e-01 7.1565944e-01]]
# Happiness
# True
# [[0.0652491  0.00124917 0.12424354 0.80925816]]
# Sadness
# True
# [[0.00313744 0.00375221 0.01836302 0.9747474 ]]
# happy
# True
# [[0.01139215 0.00253213 0.04868155 0.93739414]]
# happy
# True
# [[0.00329754 0.0620526  0.02098911 0.9136608 ]]
# Sadness
# True
# [[0.00529416 0.07841447 0.06891061 0.8473808 ]]
# happy
# True
# [[0.01467234 0.36031368 0.10531879 0.5196952 ]]
# happy
# True
# [[0.00507168 0.0583143  0.0682076  0.8684064 ]]
# happy
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# [[0.03580529 0.19676527 0.07370533 0.6937241 ]]
# happy
# True
# [[0.40997252 0.00607639 0.56406367 0.0198875 ]]
# happy
# True
# unable to delete previous audio data or no song folder is present
# True
# [[0.528516   0.00854114 0.42414588 0.038797  ]]
# happy
# True
# [[0.60000753 0.00378    0.36019284 0.03601964]]
# happy
# True
# [[0.606129   0.01152804 0.32812545 0.05421758]]
# happy
# True
# [[0.56199557 0.00934575 0.35279277 0.07586589]]
# happy
# True
# [[0.5234515  0.0169811  0.41421747 0.0453499 ]]
# happy
# True
# unable to delete previous audio data or no song folder is present
# True
# [[0.30580565 0.01222532 0.4909196  0.19104941]]
# happy
# True
# [[0.02308692 0.03620299 0.16399191 0.77671814]]
# happy
# True
# [[0.08023218 0.21740441 0.45917964 0.24318372]]
# happy
# True
# [[0.10028193 0.384619   0.35129362 0.16380547]]
# happy
# True
# [[0.22023943 0.00656923 0.5182083  0.25498304]]
# happy
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# [[0.01784913 0.08816475 0.8433499  0.05063625]]
# happy
# True
# [[0.03185279 0.16014014 0.68190646 0.12610064]]
# happy
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# [[0.13039407 0.3963346  0.3921942  0.08107708]]
# happy
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# [[0.06186543 0.06514154 0.8219551  0.05103792]]
# happy
# True
# unable to delete previous audio data or no song folder is present
# True
# [[0.05446997 0.08050135 0.830994   0.03403467]]
# happy
# True
# [[0.33150128 0.16315745 0.28514776 0.22019345]]
# happy
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# [[0.290217   0.04855644 0.43747553 0.22375101]]
# happy
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# [[0.01675001 0.01437504 0.9328272  0.03604785]]
# happy
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# [[0.01169214 0.01223067 0.9374307  0.03864649]]
# happy
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# [[0.0162771  0.03497008 0.91868085 0.0300719 ]]
# happy
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# [[0.01336519 0.06126899 0.88943005 0.03593582]]
# happy
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# [[0.02962965 0.23141469 0.6018648  0.13709089]]
# happy
# True
# [[0.36285526 0.03665243 0.1446775  0.45581493]]
# happy
# True
# [[0.11466386 0.11600637 0.607969   0.16136071]]
# happy
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# unable to delete previous audio data or no song folder is present
# True
# [[0.63930386 0.009947   0.29678896 0.05396014]]
# happy
# True
# [[0.20325233 0.04308934 0.13771461 0.6159437 ]]
# happy
# True
# [[0.01115475 0.02611124 0.12332238 0.8394116 ]]
# happy
# True
# [[0.1734815  0.00238795 0.17682329 0.6473073 ]]
# happy
# True
# [[0.01360348 0.00389985 0.06443162 0.918065  ]]
# happy
# True
# [[0.18324335 0.00192996 0.18566023 0.6291664 ]]
# happy
# True
# [[0.257647   0.00154853 0.33854273 0.4022618 ]]
# happy
# True
# [[0.17400047 0.00845276 0.36047754 0.45706922]]
# happy
# True
# [[0.255579   0.00113708 0.30130318 0.4419807 ]]
# happy
# True
# [[0.02329693 0.05037966 0.09775013 0.8285732 ]]
# happy
# True
# [[0.02644945 0.01335151 0.0627083  0.89749074]]
# happy
# True
# [[0.15416043 0.00256995 0.5163003  0.3269693 ]]
# happy
# True
# [[0.08397762 0.01243723 0.12656182 0.7770233 ]]
# happy
# True
# [[0.1623688  0.00664722 0.19402093 0.63696307]]
# happy
# True
# [[0.040986   0.07283181 0.15371574 0.73246646]]
# happy
# True
# [[0.05417584 0.0922955  0.8042132  0.04931545]]
# happy
# True
# [[0.05180889 0.14315122 0.65511405 0.14992577]]
# happy
# True
# [[0.02300946 0.39316958 0.45816365 0.12565738]]
# happy
# True
# unable to delete previous audio data or no song folder is present
# True
# [[0.01792579 0.49123663 0.30216336 0.18867432]]
# happy
# True
# [[0.02681227 0.34004554 0.3055637  0.32757846]]
# happy
# True
# [[0.03284163 0.00924748 0.5203259  0.43758494]]
# happy
# True
# [[0.05232513 0.11974342 0.1098349  0.71809655]]
# happy
